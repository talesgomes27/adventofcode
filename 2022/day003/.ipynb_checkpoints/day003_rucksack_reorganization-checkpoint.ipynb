# %% [markdown]
#  # Day 3: Rucksack Reorganization

# %% [markdown]
# ## Part One

# %% [markdown]
# One Elf has the important job of loading all of the rucksacks with supplies for the jungle journey. Unfortunately, that Elf didn't quite follow the packing instructions, and so a few items now need to be rearranged.
#
# Each rucksack has two large compartments. All items of a given type are meant to go into exactly one of the two compartments. The Elf that did the packing failed to follow this rule for exactly one item type per rucksack.
#
# The Elves have made a list of all of the items currently in each rucksack (your puzzle input), but they need your help finding the errors. Every item type is identified by a single lowercase or uppercase letter (that is, a and A refer to different types of items).
#
# The list of items for each rucksack is given as characters all on a single line. A given rucksack always has the same number of items in each of its two compartments, so the first half of the characters represent items in the first compartment, while the second half of the characters represent items in the second compartment.
#
# For example, suppose you have the following list of contents from six rucksacks:

# %% [raw]
# vJrwpWtwJgWrhcsFMMfFFhFp
# jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL
# PmmdzqPrVvPwwTWBwg
# wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn
# ttgJtRGJQctTZtZT
# CrZsJsPPZsGzwwsLwLmpwMDw

# %% [markdown]
#  - The first rucksack contains the items vJrwpWtwJgWrhcsFMMfFFhFp, which means its first compartment contains the items vJrwpWtwJgWr, while the second compartment contains the items hcsFMMfFFhFp. The only item type that appears in both compartments is lowercase p.
#  - The second rucksack's compartments contain jqHRNqRjqzjGDLGL and rsFMfFZSrLrFZsSL. The only item type that appears in both compartments is uppercase L.
#  - The third rucksack's compartments contain PmmdzqPrV and vPwwTWBwg; the only common item type is uppercase P.
#  - The fourth rucksack's compartments only share item type v.
#  - The fifth rucksack's compartments only share item type t.
#  - The sixth rucksack's compartments only share item type s

# %% [markdown]
# To help prioritize item rearrangement, every item type can be converted to a priority:
#
#  - Lowercase item types a through z have priorities 1 through 26.
#  - Uppercase item types A through Z have priorities 27 through 52.
#  - In the above example, the priority of the item type that appears in both compartments of each rucksack is 16 (p), 38 (L), 42 (P), 22 (v), 20 (t), and 19 (s); the sum of these is 157.
#
# Find the item type that appears in both compartments of each rucksack. What is the sum of the priorities of those item types?

# %% [markdown]
# ### auxiliary functions

# %%
def verify_duplicated(word1:str, word2:str, word3:str=None):
    """
    A function that compares two string and returns a list of duplicated chars
    
    args:
        word1: first string to compare
        word2: second string to compare
        word:  Optional Third string to compare 
        
    Returns:
        a string that constains chars that apprears in the words at the same time
    """
    
    if word3 == None:
        for char in word1.strip():
            if char in word2.strip():
                return char
    else:
        for char in word1.strip():
            if char in word2.strip() and char in word3.strip():
                return char

# %%
import pandas as pd
import string


rucksack_df = pd.read_csv('adventofcode.com_2022_day_3_input.txt', names=['rucksack'])

# %%
rucksack_df.head()
# Out:
#                                rucksack
# 0                    wgqJtbJMqZVTwWPZZT
# 1              LHcTGHQhzrTzBsZFPHFZWFFs
# 2  RnLRClzGzRGLGLGCNRjTMjJfgmffSffMqNgp
# 3                    WPLgsfLmLgqZvZgSRR
# 4              RbwHdbDdQFFFMvvMjbhqhZZS

# %%
rucksack_df['compartment_1'] = rucksack_df.rucksack.apply(lambda x: x[:len(x)//2])

rucksack_df['compartment_2'] = rucksack_df.rucksack.apply(lambda x: x[len(x)//2:])

# %%
rucksack_df.head()
# Out:
#                                rucksack       compartment_1  \
# 0                    wgqJtbJMqZVTwWPZZT           wgqJtbJMq
# 1              LHcTGHQhzrTzBsZFPHFZWFFs        LHcTGHQhzrTz
# 2  RnLRClzGzRGLGLGCNRjTMjJfgmffSffMqNgp  RnLRClzGzRGLGLGCNR
# 3                    WPLgsfLmLgqZvZgSRR           WPLgsfLmL
# 4              RbwHdbDdQFFFMvvMjbhqhZZS        RbwHdbDdQFFF
#
#         compartment_2
# 0           ZVTwWPZZT
# 1        BsZFPHFZWFFs
# 2  jTMjJfgmffSffMqNgp
# 3           gqZvZgSRR
# 4        MvvMjbhqhZZS

# %%
rucksack_df['duplicated_char'] = rucksack_df.apply(lambda x: verify_duplicated(x[1], x[2]), axis=1)

# %%
rucksack_df.sample(10)
# Out:
#                                          rucksack           compartment_1  \
# 257                NCwwwQwllwnvgsvZzgzFZzBzjGGGMM         NCwwwQwllwnvgsv
# 253          FQHWWCHwQmWmlqfCHSwJnsbNJnNsvttntBtb      FQHWWCHwQmWmlqfCHS
# 85   DCDdvdGsVDVsflVdQSsfSwhRJlgppgpRpbWLgJbJpgbR  DCDdvdGsVDVsflVdQSsfSw
# 55                   rqqGrrrqlnqqHqjNnVDSSSgQQffj          rqqGrrrqlnqqHq
# 125  rRHnLbhCzbbCHnHjMbzzjzFZmfQqWZQqvmhmfVZmqFBW  rRHnLbhCzbbCHnHjMbzzjz
# 39                   pSHShqgSMzVpphFnJMFMBtssdjRJ          pSHShqgSMzVpph
# 49                   mtPMbMqPMvqHHHDTTglBvsFshFFg          mtPMbMqPMvqHHH
# 142    HphMMbbMdBMHbBhhgHMnhvwFFvtrlSNRNgcRllcvcc   HphMMbbMdBMHbBhhgHMnh
# 2            RnLRClzGzRGLGLGCNRjTMjJfgmffSffMqNgp      RnLRClzGzRGLGLGCNR
# 52                             wdvwmhghhbtBMcLtwZ               wdvwmhghh
#
#               compartment_2 duplicated_char
# 257         ZzgzFZzBzjGGGMM               g
# 253      wJnsbNJnNsvttntBtb               w
# 85   hRJlgppgpRpbWLgJbJpgbR               l
# 55           jNnVDSSSgQQffj               n
# 125  FZmfQqWZQqvmhmfVZmqFBW               h
# 39           FnJMFMBtssdjRJ               M
# 49           DTTglBvsFshFFg               v
# 142   vwFFvtrlSNRNgcRllcvcc               g
# 2        jTMjJfgmffSffMqNgp               N
# 52                btBMcLtwZ               w

# %%
priorities_dict = {}

for index, char in enumerate(string.ascii_letters):
    priorities_dict[char] = index + 1

# %%
rucksack_df['priorities'] = rucksack_df.duplicated_char.map(priorities_dict)

# %%
rucksack_df.sample(10)
# Out:
#                                              rucksack  \
# 64                                   dgMSPSMdQGclRRdF
# 114          TRMrrGBLMLPtbssTGtBHwZmdQQbdNzzZZNZZdwjd
# 95                           fjCmDCGnfmTfFqrFnhqbFzqt
# 131                              cpFCVNnVBHtbfFRtMRFf
# 212              jZNNNNjmjSPjFTJmGGzswwzHwHpBsbPblhhW
# 32                               DzzwrtVFjLNnMTCTLCWW
# 76                           FWcPQrrWqflzSWpRHZCZHRSt
# 218                                  BGsGCnHmMlMwCfwT
# 283                      NffHGrWzWWgDBfTRhChCnSCWcnjT
# 128  SPRsSwSvBsPRPsqzwSVqzmhVWtLWhTDNLlTDtLTWGpNMtDLt
#
#                 compartment_1             compartment_2 duplicated_char  \
# 64                   dgMSPSMd                  QGclRRdF               d
# 114      TRMrrGBLMLPtbssTGtBH      wZmdQQbdNzzZZNZZdwjd               b
# 95               fjCmDCGnfmTf              FqrFnhqbFzqt               n
# 131                cpFCVNnVBH                tbfFRtMRFf               F
# 212        jZNNNNjmjSPjFTJmGG        zswwzHwHpBsbPblhhW               P
# 32                 DzzwrtVFjL                NnMTCTLCWW               L
# 76               FWcPQrrWqflz              SWpRHZCZHRSt               W
# 218                  BGsGCnHm                  MlMwCfwT               C
# 283            NffHGrWzWWgDBf            TRhChCnSCWcnjT               W
# 128  SPRsSwSvBsPRPsqzwSVqzmhV  WtLWhTDNLlTDtLTWGpNMtDLt               h
#
#      priorities
# 64            4
# 114           2
# 95           14
# 131          32
# 212          42
# 32           38
# 76           49
# 218          29
# 283          49
# 128           8

# %%
answer_part_one = rucksack_df.priorities.sum()


print(f"The answer for the part one is: {answer_part_one}")
# Out:
# The answer for the part one is: 7727

# %% [markdown]
# ## Part Two

# %% [markdown]
# As you finish identifying the misplaced items, the Elves come to you with another issue.
#
# For safety, the Elves are divided into groups of three. Every Elf carries a badge that identifies their group. For efficiency, within each group of three Elves, the badge is the only item type carried by all three Elves. That is, if a group's badge is item type B, then all three Elves will have item type B somewhere in their rucksack, and at most two of the Elves will be carrying any other item type.
#
# The problem is that someone forgot to put this year's updated authenticity sticker on the badges. All of the badges need to be pulled out of the rucksacks so the new authenticity stickers can be attached.
#
# Additionally, nobody wrote down which item type corresponds to each group's badges. The only way to tell which item type is the right one is by finding the one item type that is common between all three Elves in each group.
#
# Every set of three lines in your list corresponds to a single group, but each group can have a different badge item type. So, in the above example, the first group's rucksacks are the first three lines:

# %% [raw]
# vJrwpWtwJgWrhcsFMMfFFhFp
# jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL
# PmmdzqPrVvPwwTWBwg

# %% [markdown]
# And the second group's rucksacks are the next three lines:

# %% [raw]
# wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn
# ttgJtRGJQctTZtZT
# CrZsJsPPZsGzwwsLwLmpwMDw

# %% [markdown]
# In the first group, the only item type that appears in all three rucksacks is lowercase r; this must be their badges. In the second group, their badge item type must be Z.
#
# Priorities for these items must still be found to organize the sticker attachment efforts: here, they are 18 (r) for the first group and 52 (Z) for the second group. The sum of these is 70.
#
# Find the item type that corresponds to the badges of each three-Elf group. What is the sum of the priorities of those item types?

# %%
rucksack_df
# Out:
#                                            rucksack            compartment_1  \
# 0                                wgqJtbJMqZVTwWPZZT                wgqJtbJMq
# 1                          LHcTGHQhzrTzBsZFPHFZWFFs             LHcTGHQhzrTz
# 2              RnLRClzGzRGLGLGCNRjTMjJfgmffSffMqNgp       RnLRClzGzRGLGLGCNR
# 3                                WPLgsfLmLgqZvZgSRR                WPLgsfLmL
# 4                          RbwHdbDdQFFFMvvMjbhqhZZS             RbwHdbDdQFFF
# ..                                              ...                      ...
# 295  qvNnvWnvWDvSvqNtWSLWStqbcJBQwQJwQZHLBZbcmJbblb  qvNnvWnvWDvSvqNtWSLWStq
# 296                      DMtvqSvvDtntCRfwzGCgdzzFjG            DMtvqSvvDtntC
# 297                        TfdZgtmfDgqgvlLFFsFHvcvZ             TfdZgtmfDgqg
# 298                  pphWQMVjQVVBWWjRlHlHnlcLDDhcnF          pphWQMVjQVVBWWj
# 299      JQwwWVPBwMJpJwpWwGBWNzrDzSSzfgTPqTSTTtSPgt    JQwwWVPBwMJpJwpWwGBWN
#
#                compartment_2 duplicated_char  priorities
# 0                  ZVTwWPZZT               w          23
# 1               BsZFPHFZWFFs               H          34
# 2         jTMjJfgmffSffMqNgp               N          40
# 3                  gqZvZgSRR               g           7
# 4               MvvMjbhqhZZS               b           2
# ..                       ...             ...         ...
# 295  bcJBQwQJwQZHLBZbcmJbblb               L          38
# 296            RfwzGCgdzzFjG               C          29
# 297             vlLFFsFHvcvZ               Z          52
# 298          RlHlHnlcLDDhcnF               h           8
# 299    zrDzSSzfgTPqTSTTtSPgt               P          42
#
# [300 rows x 5 columns]

# %%
group_rucksack_lst = []
temp_lst = []
for row in  rucksack_df.rucksack:
    temp_lst.append(row)
    
    if len(temp_lst) == 3:
        group_rucksack_lst.append(temp_lst)
        temp_lst = []

# %%
group_rucksack_df = pd.DataFrame(group_rucksack_lst, columns=['rucksack_1', 'rucksack_2', 'rucksack_3'])

group_rucksack_df['group'] = group_rucksack_df.apply(lambda x: verify_duplicated(x[0], x[1], x[2]), axis=1)

# %%
group_rucksack_df['group_prioritie'] = group_rucksack_df.group.map(priorities_dict)

# %%
group_rucksack_df.sample(5)
# Out:
#                                       rucksack_1  \
# 37  PgTFGPgcBZPcHPFBZRjGPgwCnmwCsmSdQdThmMMMQCQS
# 61                      TTCJhDrmDpRVhvhHfffwzwfz
# 19                          wZccfslqZPFFjrFbFfQQ
# 74                            jBpCZStjBwWrQCMrhw
# 26                              cLlrNPvljRhRgTlM
#
#                                       rucksack_2  \
# 37            JbpvWtvfHblWDHJDzmndSdMQnSwCdhMdQD
# 61                            dmmdmglWcqvHvWsHzB
# 19      vvTvVWCJJZVBWCSvnVJJrhjQVMjVjzbgMQbjpphh
# 74  TvcHBzHdPPzdvFTzzJlvzdQfThrhhrhfQTWMQfWMqfwf
# 26    VmDBGnVdmJDnDBndnnVwDRvMgRsTbTzMMsgZghzzsB
#
#                                   rucksack_3 group  group_prioritie
# 37  rfvWlLlbtfJvvLJpqWbbqZRRGPVFNHVFgZNVFBgH     H               34
# 61              gdQMZbtlgQlZcMSttCNmVVrLSTTJ     m               13
# 19                    BBmNWBvZRvSqwsGwssPcmc     Z               52
# 74    bzGJJBJcJvdvBPFzddGgjZSbZZngRZNNnnsjRs     B               28
# 26              SpHvmGnSDJnwvDQqfrCPLpPLCfpF     v               22

# %%
answer_part_two = rucksack_df.priorities.sum()


print(f"The answer for the part one is: {answer_part_two}")
# Out:
# The answer for the part one is: 7727
